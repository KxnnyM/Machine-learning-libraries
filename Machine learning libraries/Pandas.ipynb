# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Automobile.csv")
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
df.head(10)
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
# 5          2                161         audi       gas        std
# 6          1                158         audi       gas        std
# 7          1                168         audi       gas        std
# 8          1                158         audi       gas      turbo
# 9          2                192          bmw       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# ...

# %%
df.tail()
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 196         -1                 95  volvo       gas        std            four
# 197         -1                 95  volvo       gas      turbo            four
# 198         -1                 95  volvo       gas        std            four
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 196      sedan          rwd           front       109.1  ...          141
# 197      sedan          rwd           front       109.1  ...          141
# 198      sedan          rwd           front       109.1  ...          173
# 199      sedan          rwd           front       109.1  ...          145
# 200      sedan          rwd           front       109.1  ...          141
#
# ...

# %%
df.tail(10)
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 191         -1                 74  volvo       gas        std            four
# 192         -2                103  volvo       gas        std            four
# 193         -1                 74  volvo       gas        std            four
# 194         -2                103  volvo       gas      turbo            four
# 195         -1                 74  volvo       gas      turbo            four
# 196         -1                 95  volvo       gas        std            four
# 197         -1                 95  volvo       gas      turbo            four
# 198         -1                 95  volvo       gas        std            four
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# ...

# %%
df.sample()
# Out:
#    symboling  normalized_losses  make fuel_type aspiration number_of_doors  \
# 3          2                164  audi       gas        std            four
#
#   body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 3      sedan          fwd           front        99.8  ...          109
#
#    fuel_system  bore  stroke compression_ratio horsepower  peak_rpm city_mpg  \
# 3         mpfi  3.19     3.4              10.0        102      5500       24
#
#    highway_mpg  price
# 3           30  13950
#
# [1 rows x 26 columns]

# %%
df.sample(5)
# Out:
#      symboling  normalized_losses        make fuel_type aspiration  \
# 74           2                161  mitsubishi       gas        std
# 197         -1                 95       volvo       gas      turbo
# 82           1                125  mitsubishi       gas        std
# 25           1                148       dodge       gas        std
# 183          2                 94  volkswagen    diesel      turbo
#
#     number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 74              two  hatchback          fwd           front        93.7  ...
# 197            four      sedan          rwd           front       109.1  ...
# 82             four      sedan          fwd           front        96.3  ...
# 25             four      sedan          fwd           front        93.7  ...
# 183            four      sedan          fwd           front        97.3  ...
#
#      engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
df.shape
# Out:
# (201, 26)

# %%
df.dtypes
# Out:
# symboling                int64
# normalized_losses        int64
# make                    object
# fuel_type               object
# aspiration              object
# number_of_doors         object
# body_style              object
# drive_wheels            object
# engine_location         object
# wheel_base             float64
# length                 float64
# width                  float64
# height                 float64
# curb_weight              int64
# engine_type             object
# number_of_cylinders     object
# engine_size              int64
# fuel_system             object
# bore                   float64
# stroke                 float64
# compression_ratio      float64
# horsepower               int64
# peak_rpm                 int64
# city_mpg                 int64
# highway_mpg              int64
# price                    int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            201 non-null    int64
#  1   normalized_losses    201 non-null    int64
#  2   make                 201 non-null    object
#  3   fuel_type            201 non-null    object
#  4   aspiration           201 non-null    object
#  5   number_of_doors      201 non-null    object
#  6   body_style           201 non-null    object
#  7   drive_wheels         201 non-null    object
#  8   engine_location      201 non-null    object
#  9   wheel_base           201 non-null    float64
#  10  length               201 non-null    float64
#  11  width                201 non-null    float64
#  12  height               201 non-null    float64
#  13  curb_weight          201 non-null    int64
#  14  engine_type          201 non-null    object
# ...

# %%
df.iloc[10]
# Out:
# symboling                  0
# normalized_losses        192
# make                     bmw
# fuel_type                gas
# aspiration               std
# number_of_doors         four
# body_style             sedan
# drive_wheels             rwd
# engine_location        front
# wheel_base             101.2
# length                 176.8
# width                   64.8
# height                  54.3
# curb_weight             2395
# engine_type              ohc
# number_of_cylinders     four
# engine_size              108
# fuel_system             mpfi
# bore                     3.5
# stroke                   2.8
# compression_ratio        8.8
# horsepower               101
# peak_rpm                5800
# city_mpg                  23
# highway_mpg               29
# price                  16925
# Name: 10, dtype: object

# %%
df.iloc[12]["length"]
# Out:
# 176.8

# %%
df.iloc[10:50]
# Out:
#     symboling  normalized_losses       make fuel_type aspiration  \
# 10          0                192        bmw       gas        std
# 11          0                188        bmw       gas        std
# 12          0                188        bmw       gas        std
# 13          1                149        bmw       gas        std
# 14          0                149        bmw       gas        std
# 15          0                149        bmw       gas        std
# 16          0                149        bmw       gas        std
# 17          2                121  chevrolet       gas        std
# 18          1                 98  chevrolet       gas        std
# 19          0                 81  chevrolet       gas        std
# 20          1                118      dodge       gas        std
# 21          1                118      dodge       gas        std
# 22          1                118      dodge       gas      turbo
# ...

# %%
df.iloc[:,:5]
# Out:
#      symboling  normalized_losses         make fuel_type aspiration
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
# [201 rows x 5 columns]

# %%
df.iloc[:,[2,10]]
# Out:
#             make  length
# 0    alfa-romero   168.8
# 1    alfa-romero   168.8
# 2    alfa-romero   171.2
# 3           audi   176.6
# 4           audi   176.6
# ..           ...     ...
# 196        volvo   188.8
# 197        volvo   188.8
# 198        volvo   188.8
# 199        volvo   188.8
# 200        volvo   188.8
#
# [201 rows x 2 columns]

# %%
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df[df.price<18000]
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 190         -2                103        volvo       gas        std
# 191         -1                 74        volvo       gas        std
# 192         -2                103        volvo       gas        std
# 193         -1                 74        volvo       gas        std
# 196         -1                 95        volvo       gas        std
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df[(df.price<18000) & (df.drive_wheels=="rwd")]
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 9            2                192          bmw       gas        std
# 10           0                192          bmw       gas        std
# 42           0                110        isuzu       gas        std
# 43           2                110        isuzu       gas        std
# 52           3                150        mazda       gas        std
# 53           3                150        mazda       gas        std
# 54           3                150        mazda       gas        std
# 55           3                150        mazda       gas        std
# 72           1                140      mercury       gas      turbo
# 101          3                194       nissan       gas        std
# ...

# %%
 df[(df.price<18000) & (df.drive_wheels=="rwd") & (df.body_style =="sedan")]
# Out:
#      symboling  normalized_losses    make fuel_type aspiration  \
# 9            2                192     bmw       gas        std
# 10           0                192     bmw       gas        std
# 42           0                110   isuzu       gas        std
# 104          0                161  peugot       gas        std
# 105          0                161  peugot    diesel      turbo
# 108          0                161  peugot       gas        std
# 109          0                161  peugot    diesel      turbo
# 112          0                161  peugot       gas        std
# 113          0                161  peugot    diesel      turbo
# 159          1                168  toyota       gas        std
# 161          1                168  toyota       gas        std
# 176         -1                 90  toyota       gas        std
# 190         -2                103   volvo       gas        std
# 192         -2                103   volvo       gas        std
# ...

# %%
df.sort_values("normalized_losses")
# Out:
#      symboling  normalized_losses        make fuel_type aspiration  \
# 170         -1                 65      toyota    diesel      turbo
# 169         -1                 65      toyota       gas        std
# 171         -1                 65      toyota       gas        std
# 172         -1                 65      toyota       gas        std
# 173         -1                 65      toyota       gas        std
# ..         ...                ...         ...       ...        ...
# 102          3                194      nissan       gas      turbo
# 175          3                197      toyota       gas        std
# 174          3                197      toyota       gas        std
# 103          1                231      nissan       gas        std
# 186          3                256  volkswagen       gas        std
#
#     number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 170            four      sedan          fwd           front       102.4  ...
# ...

# %%
df.sort_values("normalized_losses",ascending=False)
# Out:
#      symboling  normalized_losses        make fuel_type aspiration  \
# 186          3                256  volkswagen       gas        std
# 103          1                231      nissan       gas        std
# 175          3                197      toyota       gas        std
# 174          3                197      toyota       gas        std
# 102          3                194      nissan       gas      turbo
# ..         ...                ...         ...       ...        ...
# 173         -1                 65      toyota       gas        std
# 172         -1                 65      toyota       gas        std
# 171         -1                 65      toyota       gas        std
# 170         -1                 65      toyota    diesel      turbo
# 169         -1                 65      toyota       gas        std
#
#     number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 186             two  hatchback          fwd           front        94.5  ...
# ...

# %%
df.sort_values(["normalized_losses","number_of_doors"])
# Out:
#      symboling  normalized_losses        make fuel_type aspiration  \
# 169         -1                 65      toyota       gas        std
# 170         -1                 65      toyota    diesel      turbo
# 171         -1                 65      toyota       gas        std
# 172         -1                 65      toyota       gas        std
# 173         -1                 65      toyota       gas        std
# ..         ...                ...         ...       ...        ...
# 102          3                194      nissan       gas      turbo
# 174          3                197      toyota       gas        std
# 175          3                197      toyota       gas        std
# 103          1                231      nissan       gas        std
# 186          3                256  volkswagen       gas        std
#
#     number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 169            four      sedan          fwd           front       102.4  ...
# ...

# %%
data1 = [[122,"Kenny"],[151,"Sam"],[143,"James"],[123]]
df1 = pd.DataFrame(data1,columns=["Account no.","Name"])
df1
# Out:
#    Account no.   Name
# 0          122  Kenny
# 1          151    Sam
# 2          143  James
# 3          123   None

# %%
data2 =[[122,19],[151,23],[143,21],[156,24]]
df2 = pd.DataFrame(data2,columns=["Account no.","Age"])
df2
# Out:
#    Account no.  Age
# 0          122   19
# 1          151   23
# 2          143   21
# 3          156   24

# %% [markdown]
# #### DATAFRAME CONCATENATE

# %%
df_list = pd.concat([df1,df2])
df_list
# Out:
#    Account no.   Name   Age
# 0          122  Kenny   NaN
# 1          151    Sam   NaN
# 2          143  James   NaN
# 3          123   None   NaN
# 0          122    NaN  19.0
# 1          151    NaN  23.0
# 2          143    NaN  21.0
# 3          156    NaN  24.0

# %%
df_list = pd.concat([df1,df2],axis=1)
df_list
# Out:
#    Account no.   Name  Account no.  Age
# 0          122  Kenny          122   19
# 1          151    Sam          151   23
# 2          143  James          143   21
# 3          123   None          156   24

# %% [markdown]
# #### DATAFRAME APPEND

# %%
df1.append(df2)
# Out:
#    Account no.   Name   Age
# 0          122  Kenny   NaN
# 1          151    Sam   NaN
# 2          143  James   NaN
# 3          123   None   NaN
# 0          122    NaN  19.0
# 1          151    NaN  23.0
# 2          143    NaN  21.0
# 3          156    NaN  24.0

# %% [markdown]
# ####  DATAFRAME JOINS

# %%
df1.set_index("Account no.").join(df2.set_index("Account no."),on= "Account no.",how = "inner")
# Out:
#               Name  Age
# Account no.
# 122          Kenny   19
# 151            Sam   23
# 143          James   21

# %%
df1.join(df2,lsuffix="name",rsuffix="Age")
# Out:
#    Account no.name   Name  Account no.Age  Age
# 0              122  Kenny             122   19
# 1              151    Sam             151   23
# 2              143  James             143   21
# 3              123   None             156   24

# %% [markdown]
# #### DATAFRAME MERGE

# %%
pd.merge(df1,df2, on = "Account no.")
# Out:
#    Account no.   Name  Age
# 0          122  Kenny   19
# 1          151    Sam   23
# 2          143  James   21

# %%
pd.merge(df1,df2,on="Account no.",how="outer")
# Out:
#    Account no.   Name   Age
# 0          122  Kenny  19.0
# 1          151    Sam  23.0
# 2          143  James  21.0
# 3          123   None   NaN
# 4          156    NaN  24.0

# %%
pd.merge(df1,df2,on="Account no.",how="right")
# Out:
#    Account no.   Name  Age
# 0          122  Kenny   19
# 1          151    Sam   23
# 2          143  James   21
# 3          156    NaN   24

# %%
pd.merge(df1,df2,on="Account no.",how="left")
# Out:
#    Account no.   Name   Age
# 0          122  Kenny  19.0
# 1          151    Sam  23.0
# 2          143  James  21.0
# 3          123   None   NaN

# %%
pd.merge(df1,df2,left_index=True,right_index=True)
# Out:
#    Account no._x   Name  Account no._y  Age
# 0            122  Kenny            122   19
# 1            151    Sam            151   23
# 2            143  James            143   21
# 3            123   None            156   24

# %% [markdown]
# #### DATAFRAME RESHAPING

# %%
data = [["kenny",19,"Male"],["Sam",22,"Male"]]
df3 = pd.DataFrame(data,columns=["Name","Age","Gender"])
df3
# Out:
#     Name  Age Gender
# 0  kenny   19   Male
# 1    Sam   22   Male

# %%
df3_melt = df3.melt(id_vars=["Name"])
df3_melt
# Out:
#     Name variable value
# 0  kenny      Age    19
# 1    Sam      Age    22
# 2  kenny   Gender  Male
# 3    Sam   Gender  Male

# %%
df3_melt = df3.melt(id_vars=["Name"],value_vars=["Gender"])
df3_melt
# Out:
#     Name variable value
# 0  kenny   Gender  Male
# 1    Sam   Gender  Male
